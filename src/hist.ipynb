# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cell = np.loadtxt('s_8_cell.deduplicated.bismark.cov', skiprows=1, usecols=(3))
epiblast = np.loadtxt('s_epiblast.deduplicated.bismark.cov', skiprows=1, usecols=(3))
ICM = np.loadtxt('s_ICM.deduplicated.bismark.cov', skiprows=1, usecols=(3))

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))
axs[0].hist(cell, bins=np.linspace(5, 95, 20))
axs[1].hist(epiblast, bins=np.linspace(5, 95, 20))
axs[2].hist(ICM, bins=np.linspace(5, 95, 20))
axs[0].set_title('8 cell\nУровень метилирования - 46.5%')
axs[1].set_title('epiblast\nУровень метилирования - 77%')
axs[2].set_title('ICM\nУровень метилирования - 25.2%')
# Out:
# Text(0.5, 1.0, 'ICM\nУровень метилирования - 25.2%')
